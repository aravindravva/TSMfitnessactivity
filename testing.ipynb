# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd gdrive/My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
# %ls
# Out:
#  archs/
#  checkpoint/
#  cm.npy
# 'Colab Notebooks'/
#  frames/
#  hmd51/
#  labels/
#  log/
#  main.py
#  ops/
#  test.avi
#  test.csv
#  test_file.txt
#  test_models.py
#  TSM_kinetics_RGB_mobilenetv2_shift8_blockres_avg_segment8_e10/

# %%
# %%shell
# python3 test_models.py kinetics --weights=TSM_kinetics_RGB_mobilenetv2_shift8_blockres_avg_segment8_e10/ckpt.pth.tar  --test_list=test_file.txt  --csv_file=test.csv  --test_segments=8 --test_crops=1 --batch_size=8 --dense_sample --full_res
# Out:
# kinetics: 4 classes
# => shift: True, shift_div: 8, shift_place: blockres
#
#     Initializing TSN with base model: mobilenetv2.
#     TSN Configurations:
#         input_modality:     RGB
#         num_segments:       8
#         new_length:         1
#         consensus_module:   avg
#         dropout_ratio:      0.8
#         img_feature_dim:    256
#
# => base model: mobilenetv2
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# => Using dense sample for the dataset...
# video number:77
# ...

# %%
import numpy as np

# %%
data = np.load('cm.npy')
data
# Out:
# array([[ 7.,  0.,  2.,  0.],
#        [ 2.,  0.,  0., 12.],
#        [ 1.,  1.,  0., 17.],
#        [ 1.,  0.,  2., 32.]])
