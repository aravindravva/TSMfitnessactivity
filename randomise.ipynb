# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd "drive/My Drive"
# Out:
# /content/drive/My Drive

# %%
fid = open("/content/drive/My Drive/labels/tsm_dataset.csv", "r")
li = fid.readlines()
fid.close()
print(li)
random.shuffle(li)
fid=open("/content/drive/My Drive/labels/tsm_random.csv","w")
fid.writelines(li)
fid.close()
# Out:
# ['Amazing_Wall_Climber_(Must_be_Seen_to_Be_Believed!)_climb_f_cm_np1_ba_bad_2,climb\n', 'Janini_an_der_Kletterwand_climb_f_cm_np1_ba_med_0,climb\n', 'rope_climb_Olivia_Age_4_climb_f_cm_np1_ri_med_0,climb\n', 'megan_roof_climbing_climb_f_cm_np1_ri_goo_0,climb\n', 'Kletter-WM_2005-_Bouldern_Finale_Damen__Vera_Kotasova_(CZE)_climb_f_cm_np1_ba_med_2,climb\n', 'Mexican_Climbing_Fence_climb_f_cm_np1_ba_med_3,climb\n', '(HQ)_Rock_Climbing_-_Free_Solo_Speed_Climb_-_Dan_Osman_climb_f_cm_np1_le_med_2,climb\n', 'Climbing_Wall_Adventure_climb_f_cm_np1_ba_med_1,climb\n', 'Rock_Climbing_Nationals_08_Emily_Harrington_and_Lauren_Lee_climb_f_cm_np1_ba_med_2,climb\n', 'Klettern_by_Kurt_Hackner_climb_f_cm_np1_ba_med_0,climb\n', 'Klettern_by_Kurt_Hackner_climb_f_cm_np1_ba_med_2,climb\n', 'Kletter-WM_2005-_Speed_Achtelfinale_Herren_Minatchev_Hroza_climb_f_cm_np2_ba_med_1,climb\n', 'rope_climb_Olivia_Age_4_climb_f_cm_np1_ba_med_1,climb\n', '(HQ)_Rock_Climbing_-_Free_Solo_Speed_Climb_-_Dan_Osman_climb_f_cm
# ...

# %%
import random
