# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %ls
# Out:
#  archs/
#  checkpoint/
#  cm.npy
# 'Colab Notebooks'/
#  frames/
#  hmd51/
#  labels/
#  log/
#  main.py
#  ops/
#  test.avi
#  test.csv
#  test_file.txt
#  test_models.py
#  TSM_kinetics_RGB_mobilenetv2_shift8_blockres_avg_segment8_e10/

# %%
# %cd gdrive/
# Out:
# /content/gdrive

# %%
# %cd My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 317kB 2.9MB/s
# ...

# %%
# %%shell
# python3 main.py kinetics RGB --arch mobilenetv2 --num_segments 8 --gd 20 --lr 0.03 --wd 1e-4 --lr_steps 20 40 --epochs 10 --batch-size  -j 16 --dropout 0.5 --consensus_type=avg --eval-freq=1 --shift --shift_div=8 --shift_place=blockres --npb
# Out:
# kinetics: 4 classes
# storing name: TSM_kinetics_RGB_mobilenetv2_shift8_blockres_avg_segment8_e10
#
#     Initializing TSN with base model: mobilenetv2.
#     TSN Configurations:
#         input_modality:     RGB
#         num_segments:       8
#         new_length:         1
#         consensus_module:   avg
#         dropout_ratio:      0.5
#         img_feature_dim:    256
#
# => base model: mobilenetv2
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# Adding temporal shift... True
# => Using fold div: 8
# video number:766
# video number:191
# ...

# %%
import sys
sys.path.append('/content/gdrive/My Drive')

# %%
# !nvidia-smi
# Out:
# Thu Jul  2 04:49:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P8    33W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...
